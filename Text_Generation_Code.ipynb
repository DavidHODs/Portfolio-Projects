# %% [markdown]
# The end goal of this project is to build a recurrent neural network model that can generate sequence text data. Various degree of randomness via the softmax temperature parameter inorder to strike the right balance between generating predictable, realistic sequences and suprising, creative sequences.
#
# The data used for training this model is a free ebook (Magic Shadow) and can be found on www.gutenberg.org
#
# Much of the structure of the code used can be found in the 8th chapter of Francois Chollet's book Deep Learning with Python.

# %% [markdown]
# PREPARING THE DATA

# %% [markdown]
# The data is downloaded, parsed and converted to lower case.

# %%
import numpy as np
from tensorflow import keras

# %%
path = keras.utils.get_file(
    'magic_shadow.txt',
    origin='https://www.gutenberg.org/files/64578/64578-0.txt')
# Out:
# Downloading data from https://www.gutenberg.org/files/64578/64578-0.txt
# 450560/444674 [==============================] - 0s 1us/step

# %%
text = open(path, encoding='utf-8').read().lower()

# %%
print('Corpus Length:', len(text))
# Out:
# Corpus Length: 432284

# %% [markdown]
# Sequences of 60 characters are extracted, one-hot encoded and packed in a 3D numpy array x of shape (sequences, maximum length of the sequences, unique characters found in the corpus). The characters that comes after each extracted sequence (y) are also simultaneously one-hot encoded.

# %%
maxLen = 60
step = 3  #New sequences are sampled after every 3 characters
sentences = []  #Holds the extracted sequences(x)
nextChars = []  #Holds the targets or follow up characters(y)

# %%
for i in range(0, len(text) - maxLen, step): 
    sentences.append(text[i: i + maxLen])
    nextChars.append(text[i + maxLen])

# %%
print('Number of Sequences:', len(sentences))
# Out:
# Number of Sequences: 144075

# %%
chars = sorted(list(set(text)))  #List of unique characters in the corpus
print('Unique Characters:', len(chars))
# Out:
# Unique Characters: 89

# %%
charIndices = dict((char, chars.index(char)) for char in chars)
#maps unique characters to their index in the list of characters

# %% [markdown]
# One Hot Encoding of the Characters into Binary Arrays

# %%
x = np.zeros((len(sentences), maxLen, len(chars)), dtype=np.bool)

# %%
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %%
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, charIndices[char]] = 1
        y[i, charIndices[nextChars[i]]] = 1

# %% [markdown]
# Building the Network

# %% [markdown]
# The neural network consists of one long short term memory(LSTM) layer with 128 hidden units followed by a dense layer with 89 (number of unique characters). Softmax activation since the model is expected to predict or output a range of sequence beyond 0, 1.

# %%
from tensorflow.keras import layers, models

# %%
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxLen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               111616
# _________________________________________________________________
# dense (Dense)                (None, 89)                11481
# =================================================================
# Total params: 123,097
# Trainable params: 123,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(lr=0.01))

# %% [markdown]
# Function to sample the next character given the model’s predictions
#
# The code reweights the original probability distribution coming out of the model and draw a character index from it (the sampling function)

# %%
def sample(preds, temperature=1.0):
    preds=np.asarray(preds).astype('float64')
    preds=np.log(preds)/temperature
    expPreds = np.exp(preds)
    preds = expPreds/np.sum(expPreds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random, sys

# %% [markdown]
# The following loop repeatedly trains and generates text. It generates
# text using a range of different temperatures after every epoch. This allows the viewing of how the generated text evolves as the model begins to converge, as well as the impact
# of temperature in the sampling strategy

# %%
for epoch in range(1, 60): #The model is trained for 60 epochs
    print('Epoch:', epoch)
    model.fit(x, y, batch_size=128, epochs=1) #fits the model for one iteration on the data
    startIndex = random.randint(0, len(text) - maxLen - 1)
    generatedText = text[startIndex: startIndex + maxLen]    #Text seeds are selected at random
    print('Generating Text with Seed: "'+ generatedText + '"')
    
    for temperature in [0.2, 0.5, 1.0]: #Different range of sampling temperatures
        print('......Temperature:', temperature)
        sys.stdout.write(generatedText)
        
        for i in range(500): #Generates 500 characters starting from seed text
            sampled = np.zeros((1, maxLen, len(chars)))
            for t, char in enumerate(generatedText): #One hot encodes the characters generated
                sampled[0, t, charIndices[char]] = 1.
                
            preds = model.predict(sampled, verbose=0)[0] #Samples the next character
            nextIndex = sample(preds, temperature)
            nextChar = chars[nextIndex]
            
            generatedText += nextChar
            generatedText = generatedText[1:]
            
            sys.stdout.write(nextChar)
# Out:
# Epoch: 1
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.5326
# Generating Text with Seed: "instrument was patented, made and worked before any
# other sa"
# ......Temperature: 0.2
# instrument was patented, made and worked before any
# other same and state and screen of the projector of the projector of the magic lantern of the screen in the magic lantern of the screen and screen of the fact and scheet and stanter of the real in the projection of the real the projection of the magic lantern of the projection of the real in the first the ending the motion pictures of the first in the projection of the projection of the projector and show and scheet and stampfer the magic lantern of the world the screen and the screen of the project gut......Temperature: 0.5
# rn of the world the screen and the screen of the project gutenberg-tm intertance of the projector which would that the unine to the projector and the magic lantern best in the ports, schoot.
#
# experiment of projector of the ending the antient stant and stanter, drence that the stered the projection of the pictures with the projection of the fasted before uninger of the sceneder, sochung of the one of the use of the and the develope the projector, his in paris of the pictures that the artirs of the realing scientist of the trancess and a pature in the proj......Temperature: 1.0
# e realing scientist of the trancess and a pature in the projected, i age at awound the at alporing and inventions subject and man prusen who the pariswertman and chints
#   28, 1844.
#
#   other basing westents of the the peep of ah eyes also ge
# retural foung in resulshed of a sureating much will be unet of the time and shoulhed
# before up. you could correr. in 1850 winticatrism. lume hes’s, time a realy
# the tections to the facing for
# e.fer univer studges for litely with the artir gnance option projecting of mught wheng anschen7 and a
# position was helphite theEpoch: 2
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.4642
# Generating Text with Seed: "centuries later, thomas a.
# edison sometimes found it better "
# ......Temperature: 0.2
# centuries later, thomas a.
# edison sometimes found it better of the screen of the projection of the screen the magic lantern of the screen of the magic lantern of the projection of the magic shadows of the magic shadows of the screen of the magic shadows of the magic lantern of the screen of the magic shadows of the screen of the successive magic shadows of the screen of the projection of the magic lantern of the screen of the screen of the screen of the spectators of the screen of the magic shadows of the magic shadows of the magic shadows of the made so......Temperature: 0.5
# ows of the magic shadows of the magic shadows of the made so the not contersanced from theis appear and the applaced by the screen he projector of projector were arcasson was a projection of the use of the first called of the scientist conternies and the deser of the magic lantern
# scientist starraprogh of the magic lantern of the first day. but a camera and were the magic shadows which camera camera of the langenheis could in the or great and the end the musich and images of the project gutenberg the projection of problems were made so many in others of ......Temperature: 1.0
# g the projection of problems were made so many in others of ployorgrope of a was amork, collection of a tow a motion picture scientisf you come hed other, contribution.
#
# ferchm. the may would bu crliment were had also obrenc, whish withous aftrodenad of epportronagical. he
# receedelnces
# when images
# of a caleuse of volist his camera
# work of a brod”a wonder to sacksing light studiescope first nonember
# of kircher scientision problem and others were thise, on on archastrust optionianisipe, of mathema of tomed an influ it in
# 1e66, the bioks made the mld is 167Epoch: 3
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.4175
# Generating Text with Seed: "e behind
# the other, are rotated in an opposite direction, th"
# ......Temperature: 0.2
# e behind
# the other, are rotated in an opposite direction, the projection and made the stedes and see and the projection and the magic lantern of the magic lantern and a long and the magic lantern of the perfect the stedes and magic lantern and the stedes of the sun and the scientific projection of the magic lantern of the screen of the projection of the projection of the motion picture projection of the projection of the projection of the stedes of the projection and shadow picture the projection of the projection and the projection of the sun of the spe......Temperature: 0.5
# n of the projection and the projection of the sun of the spect and shadow of the applicator and the continued to smalling were time of the nearn the succession of the words and became and still represent to a place the study and the
# screen in the projection to the development of the neather and a stemena and studies and the magic lantern in the sun the a principle and the studies had to the projection and when a gove the painted and a done and projection of the first magic lanterns of the stedes of the seem the ease of the strent and a portal
#
# the specte......Temperature: 1.0
#  of the seem the ease of the strent and a portal
#
# the spected expilkor
#        project gutenberg-tm norings he defear the
# his i lucive in paris, wondon in the my hands turm, some
# his the stilled unbot the vising a projection of the fame, and wheel was few stavelfir prosectrect.
#
# cagernardorozw, in the a smele. he sten exppoddenting the valos. the screen abow cunny the parts for a tamatient which camera vay soneted a elfe”, be concernant ar
# interested his have
# de millian ubburtation,   senwd made there fal disks and france.ty before a advieped
# illusion, moEpoch: 4
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.3857
# Generating Text with Seed: "e photographs copied on
# glass slides, mounted on a revolving"
# ......Temperature: 0.2
# e photographs copied on
# glass slides, mounted on a revolving the photography, which was a second and the success which was a consider the magic lantern which was the screen of the success which was the success the first was the projector of the projector of the projector of the photography.
#
#   1855   who was a second the photography of the projector of the photography of the photography of the same and a secious the magic lantern in the projector of the projector and stand which was a section of the magic lantern which would be projector which was the ea......Temperature: 0.5
#  the magic lantern which would be projector which was the early of and had the first not considershing method of from the porta
# photography, but motion in the projector and image of a projector of a photography of magic shadows. and scientific setisted of an its the early of the starropisture the studies which was the photography of the photography and and magic lantern fictly, which consected to had a modern magic lantern which was the projector which was the scientific magic lantern scientific appear to and who with an indiciert had magic shadows silst......Temperature: 1.0
#  appear to and who with an indiciert had magic shadows silstrobing 6vision to the stare and the nature on ones. renteres etew the gich it founts howmer of the younges
# because
# his for _aberenned phosimeoht lether.
#
#   ittings. ne:
# _kirchering., kille, 1656.
#
#   chea, ventle
#               145ki  magic shadow photography, 1el:
# magic, 1iting it in
# anedentuly process includinomic aract from own demeny or perfect5
# at the stanfleation on theatriits in the wort, where is a(musius of system to “vensional success tios. the earled ig
# con. nor 8r. wide disling into shEpoch: 5
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.3596
# Generating Text with Seed: "tional purposes. it
# will be noted that cardano’s description"
# ......Temperature: 0.2
# tional purposes. it
# will be noted that cardano’s description of the motion picture and the projection first and the early to state of the screen of the projection of the first success was a considers.
#
# the projection was a spectator of the projection was a started to the projection of the projection of the screen of the projection of the first projection formations of the projection of the projection of the sun of the projection of the first and the photographs of the many could be barbaro the projection was a special started of the projection of the pro......Temperature: 0.5
# rojection was a special started of the projection of the projection which were are in paper description of the first or the considerss of the sunsersein in a compure of the magic
# lantern of the time of the matters of the first or the motion pictures of the projection of the mentioner was a new of the susceers.
#
# the aution and the principle of the first first studies and a motion picture many had the picture of the toment in paris, the devices and as the motion picture first in the projection of any latert for early to interested of the projection of the ......Temperature: 1.0
# any latert for early to interested of the projection of the street and lens to copper and shadopbery--state projection matter of the publicted or ven to lected to peachires had constuncet a fact” the proces of the scops , wertatrican with the necess appear were ond in 1822 made, described specchon and first of the certain the 8art to remoried were perpostion of paintins hyst mu)int exposition of then at time--fearttic somethanowis
# des-you”
# relied. a descriptirganeus a firtm of kirbualious on bacon debricularable annaud. in little
# went. when 19 thring
# botEpoch: 6
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.3392
# Generating Text with Seed: "gress
# under this belgian who was endowed with rare talent an"
# ......Temperature: 0.2
# gress
# under this belgian who was endowed with rare talent and the magic lantern in the sun at the projection was suppers and the suppers and the mathematical photos
# the series of the magic lantern and the sun at the projection of the project gutenberg-tm the sun arable and the secres of the sun as the sun and the shown the sun of the sun in the project gutenberg-tm early to the motion pictures of the supperias of the screen of the sun of the sun and an instrument of the project gutenberg-tm early artist, and the series of the screen of the supperiation o......Temperature: 0.5
# y artist, and the series of the screen of the supperiation of the
# photograph of motion pictures of a motion picture. a complitas fitt could be changement is being the motion pictures of the pictures work of the instrument in
# the sun armat of the britishes and studies and shows by the etgene through the show and instrument was the eye burning and with the projection of the precius shown whose state writer in motion pictures as well as for many on the over the wars in the same patent of the projection was never in the semilation of the chamber of a similar......Temperature: 1.0
# tion was never in the semilation of the chamber of a similar
# chinitusablegh from gave marey
# was ever pictures of a cameram , pintation
# scientific published music glasss arey develops in stutuent to
# the
# haching the magic
#          light and photographic but this on
# never but remarked on hen any in plates,” the spects.
#
# the same wundster of the imperman ilame was altilles of heiren by herey.”
#
# roze so also made for the originating place and he, archishon-onwers of the trebination of ”reasabratical notography. he was yous paul he rex spews to set
# the fine geEpoch: 7
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.3221
# Generating Text with Seed: "vid brewster, scottish scientist, invents the kaleidoscope,
# "
# ......Temperature: 0.2
# vid brewster, scottish scientist, invents the kaleidoscope,
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ......Temperature: 0.5
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ......Temperature: 1.0
#                                                             amous” ort--_chalaber. _vision questor, as who centory, ma-had trouble his origiesed turnes, objects a royal missions
# who useftliat the perpostical sisceltmented criduly witheably distance
# based modern age holly.
#
#   indication to chreated in charle laupfrow.
#
#   -about later lens of any cours on silver.
#
#   1356 woyf, 1961., engtever, first magn, lettle whose barber forts of his knowles arts.it mover realys. it projection of harring of with stripsia   or lens..
#
# the countch succection of 1844 duy Epoch: 8
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.3074
# Generating Text with Seed: "ave been well prepared for an
# extraordinary show after looki"
# ......Temperature: 0.2
# ave been well prepared for an
# extraordinary show after looking the project gutenberg-tm early and a sensally and standing the see place of the project gutenberg-tm edison standary of the projection of the project gutenberg-tm england the see photograph and shown the see the second and an invention of the description of the screen of the projection of the first project gutenberg-tm early and standar the see magic lantern was the second and designs of the subject was the see photographe of the secret the project gutenberg-tm edison standary and the see pho......Temperature: 0.5
# ret the project gutenberg-tm edison standary and the see photograph entertainment of the showal
# early the simules of the became and in new york was a first arts, became and the simpless from his art of the necessary of the projection he was the magic lantern for the patent of the paris of the projection of charles were a nuring the applience of system published an addition of the project gutenberg-tm entertainment became in the shown the secret and shown seen of the essent of the screen the england was the surfire and the sun edison was not colored the s......Temperature: 1.0
# and was the surfire and the sun edison was not colored the skyriminattoraly, the should be rome
#   audience or brothers._ tach elecic, at the first deschibent was he over all a place
# 2.f, he form willen applied, ease improvement were rague the kinetograph agrebued te.
#
# and muchang the motion eyear anly is indibo perl.
#
# in 180t sfoulmant well, ooptice. that of the bleg. much deteqhed and magic drawings winded for the compicianeting ovition and subject for the knowledgis-out
#   picture magic lens. cossible very never whose one described i that
# inventors of cEpoch: 9
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.2954
# Generating Text with Seed: "rab.
#
# alhazen (abu ali alhasan ibn alhasan, ibnu-l-haitam or"
# ......Temperature: 0.2
# rab.
#
# alhazen (abu ali alhasan ibn alhasan, ibnu-l-haitam or a set the projector of the projector of the subject the projector of the projector of the subject the projector of the projector of the projector of the projector of the projector of the projector of the sensember of the projector of the projector of the projector of the projector of the projector of the projector of the projector of the projector of the subject was a set to the projector of the projector of the darketical showing of the projector of the projector of the first actually and the ......Temperature: 0.5
# he projector of the projector of the first actually and the standation of magic lantern to combined the camera as in the projector and at the          schear similarse was in the since of the premiere of the stampfet lemight the background a set and the perfect in the premiere of life the a development in the projector of the project gutenberg outd so the learn and a comply was the lantern for the present man of magic lantern, a large of a set of the projectors was the had the comminted the premiere the magic lantern’s first thaumatropication of the proj......Temperature: 1.0
# iere the magic lantern’s first thaumatropication of the projector of hmating the
#          onn ushits in the eriss. the printed designs of the united with age paglue the same fant arnimited powerse of the indssing on a half, benewed for mathemationary
# on among the designs of very glamen of one the eartica, and was impression projector
# leme alghiefd camera pard
# characted was published in boaudz, was ydex noteden ma” to just the sikele tried missienting italis paris
# said. in far a nams on semy its magic llagales in their slides on
# did not added a page used Epoch: 10
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.2843
# Generating Text with Seed: "–1875), who also combined photos and
# the magic disk, in 1852"
# ......Temperature: 0.2
# –1875), who also combined photos and
# the magic disk, in 1852 the sun and the sun and the sun and the sun and the sun and the magic lantern and the projector. the sun of the sun and subjects and see the sun and successive projector of the sun and the motion picture and his device which was the sun and the sun and the sun and the sun and the magic lantern and the motion picture and the sun and still of the projector of the screen of the sun of the projector of the projector. the projector of the magic lantern strict and the subjects and the sun and still o......Temperature: 0.5
# agic lantern strict and the subjects and the sun and still of their sun and interrapher and first projector. a theatre of the obvence were showed succession of the magic
# lantern and projector of the first device to the provise of the sun at the origin of the arthers he 61 18826.
#
#                                                                                                                                                                                                                                                                                        ......Temperature: 1.0
#                                                                                     event a manuin his film usually ilcherol for kindion
# trangussens, its full supprimpting it claims to splenes from a devices, how as the apparatus of the heatters,
# monticrssols, and the meins were neatelly pictures, that the projection of the magno.
#
# may conbrut4, the entmar..
#
#        hapord to be wrotes donmark, as professor were
# notes sjourn and hollystor
# mar his obergity. that worked
# to claims,
# a projector, relieve bu ninely lander performed the france of montt in howisEpoch: 11
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.2731
# Generating Text with Seed: "ent name until it was given
# by d’aguilon, to whom must go pa"
# ......Temperature: 0.2
# ent name until it was given
# by d’aguilon, to whom must go paris of the motion of the projectors of the screen of the second and the motion of the spectators and a contribution of the spectators and the projectors of the suggestion of the motion of the device was not contributed the art of the second and a contribution of the photography of the projectors of the projector which he success in the spectators and the seemed of the spectators and the special physician of the motion of the screen of the motion of the projection of the spectators and the sugges......Temperature: 0.5
# he motion of the projection of the spectators and the suggestion of the philadelphia profession of the spectators projected the long and suggestions were to
#          of the motion of the first spectators in 1889, he was a motion of photography of action and photography of the accounted contrifution of the application of the phases.
#
# edison and willia chinital and plateau with the first was only and an engineer, concerning
# with the projectors and photography and the retalm. he suggestion of the photography in the are screen of observe many in printing and......Temperature: 1.0
# hotography in the are screen of observe many in printing and de have not recordudes
# dusel,
# fures. works poctroped by kircher contrivator, father wall, also was smalleis doceutity of  reliad projection from (y-1.edeepa return, some (or 1831 on the
# great graca
# s
# originascope accompany for viewning offician datical, influencely developed on a chus’ “feation came   of an entertainment that years, he       of scientification. a neagicient--carratis and
# outside
# achieved an optics. the art donable for the picture spugy at
# shoreties of
# the
# charge necteturel in cEpoch: 12
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.2645
# Generating Text with Seed: ", 155, 158;
#     chales, de, 65;
#     demeny, 146;
#     edison,"
# ......Temperature: 0.2
# , 155, 158;
#     chales, de, 65;
#     demeny, 146;
#     edison, 172.
#
#   semely marey, 172.
#
#   photographed kircher, 172.
#
#   semely langenheim and the magic lantern stand and one was one of the present the sun at the present of the project gutenberg a project gutenberg an archite of the period of the present the words on the present the words and the successful pictures were to the best in the project gutenberg one was the motion pictures were as a secondel of the project gutenberg an instathed by the presented the distribute it was the states with the prese......Temperature: 0.5
# he presented the distribute it was the states with the presenting and the pictures of the soles to all the magic lanternation of the eye stepe of the arts for a states before the films of the present precial instead of the motion pictures became a mensuring with the projection of the artist, source of the magic lantern pictures or projector was made the magic lantern device of the pictures was not developed that and magic lanternations of the patent of the early armet experiments which to magic lantern and interested in the problem of the _gaging a natur......Temperature: 1.0
# lantern and interested in the problem of the _gaging a natural publish to kinetograph to shadow doge heinly dooget the mechanicar medium.
#
# a types of the applecitia magic linest. washons, considerable problems kepler
# philosophonogia
# are of a mirror for meansing on the work in 1894 arr, and suysess
# of copjectures as noted. and same important word to successful tome of the greatest the had one wonders you lource are instutured. the first notion of the camera to other see magnically the studied for homarial wasted out noh of the camera
# lens. later thar
# simpEpoch: 13
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.2585
# Generating Text with Seed: " ser piero da vinci was born near florence in 1452 and died
# "
# ......Temperature: 0.2
#  ser piero da vinci was born near florence in 1452 and died
# the recommenting the magic lantern of the screen of the secret to the secret of the surply of the screen of the screen of the project gutenberg the project gutenberg the screen and the secret of the screen of the project gutenberg-tm editor and the screen of the english of the screen of the screen of the screen of the project gutenberg the secret of the screen of the screen of the magic lantern of the screen of the project gutenberg-tm electronic works of the screen and the sun at the screen of ......Temperature: 0.5
# electronic works of the screen and the sun at the screen of the first american in the sun explaining the change of his project gutenberg-tm earlier in 1885 projected of the project gutenberg the secret and the sun and a set of the strong of the films in porta it had been acker seen to his film projection in the magic shadow and shadow plays in the magic lantern in the secret of the magic lantern and porta had the entertainment of the screen of the sun archive et
#
#   1880   who was about the showd the method
# of the first device concerning in the perious on......Temperature: 1.0
#  the method
# of the first device concerning in the perious on a projector of 1806,0 on the only, stereomostor of previeshed
# applased phenomenon toptical also reading as on
# the persistence but it assicuto would in rear ay
# peep-show at _xt  into the iten _period to naked for
# early far had model of octlation stood becaured upon was imp successful under and the musium hus machine and renavinment. the
# motion picture scientist develops would he had from his grolongem 90 paper of right the apardd in galises are itsiberd, he recientive of langenhit “of muybridge Epoch: 14
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.2496
# Generating Text with Seed: "                              oculus artificialis teledioptr"
# ......Temperature: 0.2
#                               oculus artificialis teledioptrical scientific paris, in the institute was a second and the first projector which was the paris of the projection of the paris and the work was the photographic shadow projector which was the projector which was the projector of the projector of the comment the magic lantern and the screen of the projector of the work in the work in the project gutenberg-tm electronic works on the projector which was a states which was a projector of the screen of the projector of the comply were as a comment a......Temperature: 0.5
# he screen of the projector of the comply were as a comment and the originations was a later was well as the work by a great projection in the audiences. he was as a projector which could be in projector which was a stame with a small and the original comply with the they work by the motion pictures are made of the photographic also be the trided the magic lantern of the projectors in the united states in the films of the phantagraph and the instrument of the first projector. the late and in the also series of the comment could be the first
# autona. stampf......Temperature: 1.0
# also series of the comment could be the first
# autona. stampfery drawings construction ared mihros as surface, wished to shadlo rapids of his
# editions find’ devices ppeas to publidic representastory
# syrage prerofle of optical
# to blirk second and other first of the actails action. abovated phantas, projector.
#
# rehaure through i ingeneneds
# with fame creat but politic lated more and ingenious.
#
# at observe
# motion, had animalmania, “and beslir,
# personables.
#
# charled by the uphationa,
# soed who ligned used for his hiffurl of the year thr
# edgmons. years of seatesEpoch: 15
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.2447
# Generating Text with Seed: "maker, constructed cameras and projectors
# in england._]
#
# [il"
# ......Temperature: 0.2
# maker, constructed cameras and projectors
# in england._]
#
# [illustrus_ xvii
#
#   _camera obscura_ and the motion picture scheet which would be still of the screen of the screen of the story of the presiscord and a first a second a second and a spectator and a device of the sun at the project gutenberg-tm work of the project gutenberg-tm work of the screen and a second a study of the stereof wheels to the stampfer and the magic lantern and a success of the screen of the screen and a second and a study of the magic lantern and a second that the motion picture ......Temperature: 0.5
# y of the magic lantern and a second that the motion picture a little addition
# of the action of the second so images of the latham, in the screen in the deviced that a large camera and a projector which project gutenberg out that the strome of the eunling to be success to the part of the december of the stereof and glass.
#
# produced or motion in designs for his all the about and which about creargh the project gutenberg-tm hous of the also a
# stirto will sesting that the motion picture projector of the projection that the light and shadow phonograph as well......Temperature: 1.0
#  the projection that the light and shadow phonograph as well noticity of motion
# pictures is he all subject and only spectatorn melary. murt was sormantel’s god the gad
# mirror, the apparatus michane motion
# picture screen add to kircher. and avoy was
# porta’s
#          creation of avaracs, sold claimed from a now john actually appledit a glass. but
# he bucless
# of form. after motion and glass with glass slide of atteially distruction and powlumed any poscted to
# views. an
# the ”ally and instructed had deenching
# also friend in the picture whats edbstole and made Epoch: 16
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.2391
# Generating Text with Seed: "        a description of the magic lantern spreads the use o"
# ......Temperature: 0.2
#         a description of the magic lantern spreads the use of the projector which was the projection of the projector which was the projection and another with the projector which was a state started the projector was a motion picture with the projector of the magic lantern and the second and the scientific and an optical in the projection and seen to including and the sun and a devil in the motion picture work on the projection of the projectors of the periar and the projection of the projector and an at the projector and the magic lantern and the start......Temperature: 0.5
#  and an at the projector and the magic lantern and the started in seen the pictures of the magic lantern in the work on see and became place with the projection of the bring the scientific secretable and ingenious or any manufician of a sold commencition of the period the picture spectator of the screen and the period
# in the end of the motion picture was the studies became a first the successity of the part of the projection of magic shadows for his editod before the periaring explain and were resulted on painted with the first work projectors and the pe......Temperature: 1.0
# esulted on painted with the first work projectors and the perial subjects of project gutenberk de.
#
# in 1890 balop, in                                                                                                      piblation a
#                                                                le secyition                                                groun eard_ and that camera was governe. _neyghtoscope,                           projection and
# herched, 176.
#
#   s. similp, 142, 114, 146, 106, 1erma_ marey, 160.
#
#   usemigston, 172.
#
#   maulor is
# possible Epoch: 17
# 1126/1126 [==============================] - 7s 7ms/step - loss: 1.2314
# Generating Text with Seed: "nd reflect the outline of
# the design in what seemed a magica"
# ......Temperature: 0.2
# nd reflect the outline of
# the design in what seemed a magical the magic lantern and a seen and a special scientific second started the first to the projector and had the magic lantern of the projector and his first to the photographs of the projector which was the projector and a special scientific about the motion picture are the scientific works of the screen the artist and a special scientific are as an indelled an instead and a spectators in the photography of the artillery in the photography of the screen the magic lantern and a contribution of the ......Temperature: 0.5
# y of the screen the magic lantern and a contribution of the motion picture articlally of the original projector and a disk
# of the instantory of the day and intermittent to speed to in an optics and was the motion pictures who was the new of the projector and pointed of the vision of the modern motion picture set donisthorped the photography of the art in the enghiment of the phonograph.
#
# and intermittently sold by a motion pictures, hyporing the experiment.
#
# from the showmen and the talking the medium in the men of marey to make the screen the eye.
#
# the ......Temperature: 1.0
# medium in the men of marey to make the screen the eye.
#
# the midrumination
# or the gim-a comporices to magnionor
# gaghoraticoples, bj. hzbtovionial about work on olderens granted to developed, his studie
# stor
# devico and successfuter. pictures which
# for
# his learned marey fundor. an augince of hilly used magnishing murs lanter and many
# the engineer, with englain of the mie stits about as he in advances in this has burning the
# comerics curiouted on and euphinning cours, scientific showing have and the engines of
# his did not not only worked on his medium.
# a tewEpoch: 18
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.2252
# Generating Text with Seed: "nation
# of lenses which would bring far things near.
#
# roger b"
# ......Temperature: 0.2
# nation
# of lenses which would bring far things near.
#
# roger being the motion picture are the projectors at the magic lantern of the art of the screen and the star and a projectors at the first modern projectors and the projectors and the start the projector of the magic lantern at the stropp were the magic lantern and of the projectors and the the world of the art of the projection of the art of the projection of the shows of the state and the entertainment of the art of the art of the projection of the state and the magic lantern of the complete results ......Temperature: 0.5
#  of the state and the magic lantern of the complete results of the light and shadow arts of the projection and that they at a camera at the star and considerable
# and that the scientist of the work on the batthan in a light and shadow
# and commented and a devices and in the projector and a work of the magic
# lantern and the manufacture of the facts, and the projector which of the best magic lantern once a device to the legition of the curtres were at the art of appried and invention of the experiments of the bestrited the projector, and or projection of the......Temperature: 1.0
# nts of the bestrited the projector, and or projection of the geo7inci’s describse died that by by john akirvert, and stars their
# attention in the first historia wat for the anognas itains of new
# portion to and the
# later at
#   have rehill
# its nva cleares sound
# in which head of experimented but tscopibuce lons.
#
# well as
# provited his royal days of kircher and only more color too the history of motion of printed a
# complate of rathee added to remay, and life the
# disk of tring pellects whene then,
# practions afterna,
# at the lathe projection. he authter college sEpoch: 19
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.2198
# Generating Text with Seed: "ographic devices of marey and others
# were relatively clumsy "
# ......Temperature: 0.2
# ographic devices of marey and others
# were relatively clumsy of the projection of the art in the screen of the show and projector. the end of the screen of the screen of the motion picture archites of the screen of the motion picture archive was one of the projecting the motion picture secreting the magic lantern shows of the projection of the screen of the screen of the camera which was the magic lantern and the screen of the first experiments of the screen of the screen and the projection of the sun at were and the magic lantern, and the magic lantern a......Temperature: 0.5
# e sun at were and the magic lantern, and the magic lantern as a secreted with the successive shows, muybridge, the end in the system was one of the universal screen of the united states or the art was as as a projector
# were set time of the sun, charlos of the united states before the screen of the projection of a successful interest in the magic lantern of the effects of
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# the work on a theatres of a sun arrament was made or years in the screen of real the magic lantern as the origine and shadow plays were projector and a art which was the english in marce......Temperature: 1.0
# lays were projector and a art which was the english in marcels device battocornatic notory instrument (1 on observe 7there one in 1886, experiments somephance.”
#
# realy
# ushaucal art.
#
# back, th: as
# the first also during glassing and a hund1. then was the cortion
# the peleingly of
# the geieninia was obfainion of the jesuntde of a proved
# with a reporter at the
# thearval exhibiting to teid.
#
# in london defusion bescreid of was no records and _la know and thought made with
# somethcodires wall action.
#
# steel phirci of picture.. exhibiting pelacisascopes.
#
# storme
# in Epoch: 20
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.2134
# Generating Text with Seed: "r senses really work.
#
# alhazen did valuable work himself but"
# ......Temperature: 0.2
# r senses really work.
#
# alhazen did valuable work himself but the model of the scientific work of the model of the first model of the first to the motion pictures of the art of the sun and the sun and an as the motion pictures were made to the work of the projection of the motion pictures of the magic lantern of the projection of the sun and the sun and the similar scientific work of the sun and the see of the sun and the model or the state of the motion of the sun and the motion picture as the sun and the model or the projection of the sun and the model ......Temperature: 0.5
# un and the model or the projection of the sun and the model of magic lantern to the day of a concelt of the first description of projection which were interested a set the original march of the similating and any others in the spokes of the projection in the light of the world was given to a magic lantern, and a first amort-so donations interesting shadow scientific exposited the projection work on the projection of the first porta concelted to make with out of the photographic show.
#
#   1833   the surfaces in the magic lantern, and the method was publish......Temperature: 1.0
# he surfaces in the magic lantern, and the method was published ita. “a deforms. nome, relations.
#
#   1855   raption, he developed, the hass, was not, a usever, which laming glasse, when a profess moming a degafe that poler the photobress were willinging prawration which also age of the day was knewanivain, wheel undersitgy filu of model used
# or pictures, nomble
# work should so magic shadow paces of haid of seein, was place and the
# end picture and his particular. there is no after
# too
# latim of the eye the nome were at the
# europped-wald to be toyed the late Epoch: 21
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.2115
# Generating Text with Seed: "ry but for the common good.”
#
# in his latin autobiography kir"
# ......Temperature: 0.2
# ry but for the common good.”
#
# in his latin autobiography kircher’s projection of the projection of the projection of the screen shows, and a motion picture are the projection of the projection of the sun of the projection of the projection of the projection and the projection of the engliss of the projection of the profession of the profess and the projection of the earth.
#
# physician of the first a second and interest as as the langenheim projection of the earth. he was a second so interest in the sun as the projection of the projection of the phonograph......Temperature: 0.5
# he sun as the projection of the projection of the phonograph of the lantern was the perforas of the process of the best after early first edition of the camera works on the sun and professor of the first model was all stoper was science of the spectacle and the time of the projection of the screen which sources of the demonstration of the magic
# shadows also interest and when the langenheim and the mirror the projection of the honogine of a motion pictures the public dickson of some science of the effects as in 1884 on the periapion,
# and the langenheim fo......Temperature: 1.0
# e effects as in 1884 on the periapion,
# and the langenheim formignted by the later. spead” for the ghost of phonograph as gaston plateau improbe-him words tuoner magic
# lantern cardd with england
# of motion picture, accuratelint themas
# in subjects to seem what simple triden,
# andwen at the louicishers distates the problem was used may satis rendaofcle made it holded england.
#
# le the first essention after public not, the would on the subject affection was known regented in uppoa, thvereders and rights on the origined as the rand used with what who kinetographEpoch: 22
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.2056
# Generating Text with Seed: "er it was said, “it is a matter of much less importance and "
# ......Temperature: 0.2
# er it was said, “it is a matter of much less importance and a first to the projection of the success was a concerning so images as the screen which was the sun at the arts and the screen of the screen of the screen the motion picture are the screen which was the projection of the first all the projection of the sun at the first projection of the magic lantern as the projection of the screen which was the projection of the spectator of the screen called the sun at the archimedes were archimedes and a projection of the spectators in the screen was a concer......Temperature: 0.5
# nd a projection of the spectators in the screen was a concerning projection of the projection of the mirrors. in italize in his story of the earliest had motion picture archimedes was edition of the photography of the spectators at the decided to the motion picture archimedes had not the improve and magic lantern of the sprussing of the surchyre camera and the persistence was a camera the part of politic magning and a controlled future and the motion picture projection of the pictures as porta concempice and a position of 1894,
# for his light also howmat ......Temperature: 1.0
# oncempice and a position of 1894,
# for his light also howmat motion, plaolax by claudetiws, for slour thy
# son agreea. sented.
# this new for this certain to trentnimed and him.
# in portable
# successfulxte his _light seat the phenomene.
#
# early incren the projectgjm-’s omital smallical mindid to lens. as the history. mirror the institual of
# limitast it in motion pictures use, for optics. long others.”
# to may cuplover the collecte the magic lantern scroen, concerning camera had an adsfirated it he martinich vos on the mirror
# cours. but lilled the first buctle
# haEpoch: 23
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.2025
# Generating Text with Seed: "rtifying and defending and attacking according to the french"
# ......Temperature: 0.2
# rtifying and defending and attacking according to the french projector was a projector and a projector was the secrets of the strong projector of the secrets of the secrets of the english and the strong photograph and the projector of the projector was the edison was a projector was a studies as the projector of the secretation of the projector of the projector of the projector of the screen of the screen of the art of the screen of the art of the arts and projector of the projector of the photograph of the magic lantern and the magic lantern and a proje......Temperature: 0.5
# graph of the magic lantern and the magic lantern and a projection of the english as who he was a studation of the early
# action of the use of a giver and a volumeimans were the invention of the magic lantern and others. in the secrets of the problem which was been accomplial paper internion of the showman, and the more projector
# or the strongs
# optical arrangement of the projection
# dund the secretance of the sun the discovery of
# the indeding or low could be could be fas contermy or an other motion pictures by the included real motion of the same camera on ......Temperature: 1.0
#  pictures by the included real motion of the same camera on the
# ignoss.
#
# paul a were others was fame, the _light irations athed by patents
# covery or atserver the developt or coblariscoprabors in 1832 and was noted in spew colors, art of the perberact estances, aiming which the
# enster_, that
# noid who comsion series, -assign
# office or talens had the day.
#
# he makes in silver
# edisonon
# dexyewner his eyperre conanefic ... having the succession models thrown
# make an evant
# by in the electric into dening period and recoove because hel at a showman of the datum anEpoch: 24
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.1971
# Generating Text with Seed: " little....
#
# there is the germ of the motion picture--a real"
# ......Temperature: 0.2
#  little....
#
# there is the germ of the motion picture--a real the photographic projectors of the projection of the projection of the projection of the projection of the phonograph and the projection of the projection of the photographic projection of the projection of the sun the projection of the projection of the first and the words of the projection of the photographic projection of the sun at the screen of the projection of the projection of the sun the projection of the projection of the projection of the projection of the projection of the projectio......Temperature: 0.5
# jection of the projection of the projection of the projection of the stame of the projection in more in the art-science of the set of the screen of the art-science was the works of a stirm himpite of the sought the art-science which was the order of the seventing scientific and the medium which is developed to an almond.
#
# the experiments. the sun all the commencing the efforts in the great first in the end of the reacomana and the discoveriey was more the light and shadow and works of the
# action of the arts of the discovery of the first sun he came untin......Temperature: 1.0
#  of the arts of the discovery of the first sun he came untine
# houver could be obtained that kircher’s
# end to satt scheen words donisthordugraph boked
# using known at the _gaving toward there was ajting the effect. the did. to hemarf premiere--not heise.
#
# playor and
# .
# stillically, french says
#          eyes “special instemph or twam dacnering in
# own at the
# days of
# motion
# patent were, on the book and the active seough introduced this works of the came in perfond in the
# madough them of fruncitation of the _walls skordder artis_ of
# position of
# scenn introducedEpoch: 25
# 1126/1126 [==============================] - 7s 6ms/step - loss: 1.1921
# Generating Text with Seed: "o
# greatest american contributors to the practical developmen"
# ......Temperature: 0.2
# o
# greatest american contributors to the practical development of the projection in the photographic photographic photographic photographic photography were projection of the screen in the strange and the first the second a modern and the photographic pictures of the photographic projection of the projection of the projection of the sun and the first see of the photographic projection in the magic lantern and the photographic projection of the photographic projection of the photographic projection of the projection of the first projection of the projectio......Temperature: 0.5
# n of the projection of the first projection of the projection of the time in the motion pictures had not in the present the first motion pictures where the end of the complete the real achieve of the period to the light and shaden first form of the photographic photographic projection in the magic lantern as a prectication of the magic
# lantern described the magic lantern science of the second and a special archive five disk and the camera and wheel of the end of the united statess and projection and had colleged the results of a studies which he may be s......Temperature: 1.0
#  and had colleged the results of a studies which he may be sorder to unived the musschen sa2, he carry were not opening
# the observerance in greece prepare--this reveroouns had intereess:
#
# resulty projection dee lilied germany long arusolders in stanford
# disk which war a intence the generally projection and found that cwratee of the eye
# ...
# here was the entertainment and ferthest the history of the problem which the sea the movement of never mirror also put even a curied did not coppent in soliging rown the film moved
# french not ent. un phantasmagors goslishey tradie, they
# deviced for “the, the face of receivning wheel of lumière in his also paris, on sibliffer onating the year been autolyse was became annound emillery
# much aconch general. in 1894 this withans and copy sripn, the sroglos move bacon had satisfiged that, and with the shadlas for mexaurations.
#
# edison gold that he also did notEpoch: 52
# 1126/1126 [==============================] - 8s 7ms/step - loss: 1.1161
# Generating Text with Seed: "is placed in movement by
#   means of the handle, (d), the spe"
# ......Temperature: 0.2
# is placed in movement by
#   means of the handle, (d), the spectator science. his magic lantern and the showman of magic lantern armat and the magic lantern and the projector of the entertainment introduced in the project gutenberg magic lantern and the sun at the magic lantern motion picture projector which he had in the projector of the motion picture and the background on a project gutenberg magic lantern and the sun at the magic lantern projector and the second the strange in the screen and the motion picture and the magic lantern and the magic lantern......Temperature: 0.5
# e motion picture and the magic lantern and the magic lantern archite the projector.
#
# the new aborogram thouschria giof the english pictures as the magic lantern light and shadow showments had a screen and interest and the improved projector of the end of the lathamn, his subject of the projector of the section of this still of the niergance and the project gutenberg magic lantern in the magic lantern projector of a professor of the presentation of the period of the early striggs.
#
# action of observe the projector of the magic lantern started on a project ......Temperature: 1.0
# rve the projector of the magic lantern started on a project gutenberg eye propicat so introduced detailen of lidiaing helpted in trage and
#
# i
#         llumonis apparatus a motion in 1887
# picture, 145.
#
#   chaptor many manuscraply: 18), 125, 190th and interested in tryinestevition
# age, marey, and history or conors,
#
#                    edvertic devices.
#
#   1844   franz docalis           pootted, bothy, c.
#
#   roog.
#
#   phenoscope of kircher, 174.
#
#   attricalabo*mque philosophy. franthenn, 1852.
#
#   vaudxe kircher, which he sailk method, the nusitid which
# correEpoch: 53
# 1126/1126 [==============================] - 8s 7ms/step - loss: 1.1152
# Generating Text with Seed: "ph, the photography of motion.” he also noted that as a
# barr"
# ......Temperature: 0.2
# ph, the photography of motion.” he also noted that as a
# barrines magic lantern and sciences were all the first a secret of the magic lantern and the subject of the project gutenberg-tm edison work in this work in this work in the period or fitted the sun at the subject was the first projection of the projection of the projection of the projection of the projection of the project
# guter and the motion pictures and they we not been to the subject was a study of the subject was the subjects were also at a success by the sun a see magic disks in this magic la......Temperature: 0.5
# o at a success by the sun a see magic disks in this magic lantern is also described by schein with a sun added the some
#          an a second the first to be scientists of the real of the spring a complete in this indent in little motion pictures and a study of the screen of the system of the period of magic lanterns sented to the sun all over they were in all the england of the project gutenberg-tm edison rextdien.
#
# years devices by the bases of the project
# guter and the revision of magic lantern and the best and supprin which recognized the sun archimed......Temperature: 1.0
# n and the best and supprin which recognized the sun archimedes and the
# england of crigio also all othergy french each side
# rubbblon many effect. the
# first people in a large the physicientation for public instried of the motion picture delived they www.
#
# though the work to adjust.”
#
# the scene.
#
# living apporates of the preasight from mathemating; fairic.
#
# living points that pictures for this little sun below and simultanceysco complete west the debut i porting his obmeationation writed on challor, with the days are did. pictures.
#
#
#
#   roms. _wall of book eEpoch: 54
# 1126/1126 [==============================] - 8s 7ms/step - loss: 1.1165
# Generating Text with Seed: " his
#          efforts came after becoming interested in phot"
# ......Temperature: 0.2
#  his
#          efforts came after becoming interested in photography of the screen of the project gutenberg-tm who asportion of the studies of the magic lantern and the showman of the project gutenberg-tm real complete the studies of the project gutenberg-tm elsewheels and the magic lantern and the magic lantern and the secret to the project gutenberg-tm elsewhere the studies of the project gutenberg-tm or the showman of the secret that the studies as the scientific disks and shadow showman, who appear on the science of the later the scientific projector ......Temperature: 0.5
# appear on the science of the later the scientific projector and more than the spectators of the entertainment of the pullise action of such a more life-size also the action of the seen
# the the second, a continued to the first he conteded the lat for the introduced and shown well as
# to the screen had a contriment and the apparatus of reproduce the artist of the secret which with the project gutenberg-tm edition langenheid series of the spectators of the interpical entertainment of the strips which the first motion picture projection which he was a camera ......Temperature: 1.0
# h the first motion picture projection which he was a camera here scene of the fact the
# english sciences, attempted to helpications our
# selve copyright the pattern projected magic disks of its great impuits of althot after visitus cameras, jopuriustution, photography.
#
#   1892   seemantes kircher of magic
# lantern for the prriment and
# its the world had by made a form object redivelyoned ;                     _photoptigraphica (_spocis’ sprought.
#
#   came later, photo joyrons, trus of the funct later american system. the studemat
# to the
# projector.
#   piace in Epoch: 55
# 1126/1126 [==============================] - 8s 7ms/step - loss: 1.1139
# Generating Text with Seed: " superiors money to buy
# pens and pay copyists. certain autho"
# ......Temperature: 0.2
#  superiors money to buy
# pens and pay copyists. certain authorition of the screen of the section of the scientific and intermittent to the photograph of the screen of the projection of the screen of the scientific sectection of the screen of the section of the scientific section of the projection of the scientific projection of the scenes of the screen was a startly and the subjects in the earth.
#
# access to the projection of the scientific projection of the scientific sectection of the projection of the projection of the scientific projection of the story......Temperature: 0.5
#  of the projection of the scientific projection of the story of the motion of the meening and some scientific projection of the original or theatre in the first and the first picture projection are somethen and the he some specision of commenting the art-science and the scope of the sun of the phonograph to the light and shadow showman.
#
# in the langenheim orive and still the projection reporte actually instruction to the united states made to the time of a comment to commerciale of the world and the two long the art. this was conseraler on a number of in......Temperature: 1.0
#  the two long the art. this was conseraler on a number of instrument of lambhating
# on also first on the eploscon attution top were burning a neverin, on the callogic. as a lens of that screene innogienting scener of ochaj.
#
# the method and machines at the shutter stortical manufacter by claude before the find who kepterd with called
# war to 1833 he be used for
# how mounted audienced that some positive scientific and under the imagination or drhan edition. from 73 cevalucing
#   obpersation,
#          solve._
#
#
# tills. vasing the
# _plasil had hon projected
#       Epoch: 56
# 1126/1126 [==============================] - 8s 7ms/step - loss: 1.1086
# Generating Text with Seed: "hout life maintained a lively interest in many affairs. he w"
# ......Temperature: 0.2
# hout life maintained a lively interest in many affairs. he was interested in the magic lantern and the project gutenberg-tm and the stame of the magic lantern and the project gune magic lantern and a real also started the scientific projector of the first and a study of the special science of the striggs of the project gutenberg-tm and the motion of the project gutenberg-tus about indered the stanford was a many the magic lantern and the art of the spectators were not a stanford of the first a motion picture projector was a stanford was a projection of t......Temperature: 0.5
# otion picture projector was a stanford was a projection of the english his mathematics of the shows. with a donisthorpe and a project gullum in the heast of the project gutenberg-tm europe
# of two life and the early development of the french simulation of the day and will merrens. it is plateau, and the subject and series of as a greeade, givenbergut pasition but as a magic lantern included a few was a projection of the united states was the magic lantern light and shadow, in light and shadow and photographs of the first projector.
# though stanford. he was......Temperature: 1.0
#  photographs of the first projector.
# though stanford. he was aiver.
#          observed mavingians he developed living that called to be refiness the
# essistews billeran discovereu’s patrsity work much was a connious
# my its cordiua phenoment was some for he was elsewel of chimbent,
# this chapt lectides,
# far archimeder been other. he had practsly explained that to
# a. he was as it was a march 16, photographs. is drive was the _busing a shutter of the world in a screen hascess come to the late gall for would be allest known.
#
# and faraday comage the march ather-Epoch: 57
# 1126/1126 [==============================] - 8s 7ms/step - loss: 1.1068
# Generating Text with Seed: "was to the fact that heyl, a man fifteen years his junior, h"
# ......Temperature: 0.2
# was to the fact that heyl, a man fifteen years his junior, he was a projector and a special saci. he was a successive projector and a secret was a subjects because the sun at the motion picture and the secret the projection of the second and a many and at the sun and the motion picture projector and a special system and was all the sun at the sun at the projection of the project gutenberg ewilish and the instrument of the experiment of the screen of the motion picture and seen on the project gutenberg eark and interest to the sun at the article projector......Temperature: 0.5
# enberg eark and interest to the sun at the article projector was destracted and a
# motion picture screen in the energetius of the day and
# his disk and an entertainment in motion picture even though the
# vision in 1887, in 1886, and the are was not device. the image of the camera and a writicated in magic lantern and projector of a projector for the showmans of the study of the projection
# disk was described it was been at the stame of the early the study of the camera and comments of the projector of the magic lantern in the audience for
# the later his objec......Temperature: 1.0
# of the magic lantern in the audience for
# the later his objects remated that he was a motion.
#
# dusiae first spectators of the some light and shadow, to theall, carrie.
#
# treatrs. his nep sought, with this room had in greek .3,
#
# platets its merkled by inemberapn’s inventor of the first
#          magic siumshovay, in other sun-bedire real at animate these tradees, donatiors, and a projector at
# experiment and alfasd first augsone. the photer in complet experiment. they would so overcas perfection or said apporarls himself, countorized the art-scrupk which fourEpoch: 58
# 1126/1126 [==============================] - 8s 7ms/step - loss: 1.1073
# Generating Text with Seed: "llen while ice-skating and had
# suffered an injury.
#
# from 161"
# ......Temperature: 0.2
# llen while ice-skating and had
# suffered an injury.
#
# from 1610   the projection showing of the study of the study of the screen of the strong light of the subject was an instrument of the sun at the sun at the sun at the sun at the first projection of the first and the subject was an institute of the strong light of the subject of the first of the sun, the projection of the subject which was a strongal and the magic lantern in the strong light of the study of the first projection of the first and then to the projection of the projection of the strong ligh......Temperature: 0.5
#  then to the projection of the projection of the strong light of the projection of the first projection of the possibilish seraphs were used the projection of the first methods
#          danilar many sciences of the option of the world and stampper design was an are the first projection of the semution of projection of the secrets in the magic lantern to the first possibilia”, “the first strange of a stilles and the spectator and the same year and many that the showman of the first personal world photographs of iten is move but it was the strong light was......Temperature: 1.0
#  photographs of iten is move but it was the strong light was retor of a studying the various rudokniay in the lins of trime in 1878 ifent-onymayr. reflection detail from the eyeition of a subming obractuly fashmosper.
#
#       century._ “thancesm of piotional science, reason had oclia
# woslerous it poonable on the plateau paper, previously slides.
#
# plateau which were used his mam.
#
# pasin giod making by the project-city of groft, 137y mage, 1895; marey was fame in the late ha man explan.
# rapid and stratus of the photographs of times.
# the public to louis thaEpoch: 59
# 1126/1126 [==============================] - 8s 7ms/step - loss: 1.1038
# Generating Text with Seed: "set of stills mounted on the edge of a disk.
#
#   1884   georg"
# ......Temperature: 0.2
# set of stills mounted on the edge of a disk.
#
#   1884   george decided to the projection of the first projector of the projection of the project gutenberg instruction of the projection of the screen of the projection of the screen and school of the first all the phonograph of the projection of the first projector and a motion picture as the motion picture or a continued the projection to the project gutenberg a motion picture are as a development and a spectator and a series of the stereony. his entertainment in the screen of the personal saciorignor and ......Temperature: 0.5
# entertainment in the screen of the personal saciorignor and so that the sun statle of the walts of marey particular and the single scientific projector was the audiences were used to record and a standal movements was the end of the slides in the late and premiere which was a developed the artillery to the first project gutenberg a motion picture machine which consulted were natural produced many others the pression of the pattern motion picture archime to use the success and piett as well as a projection of motion picture was blemed to continues of the ......Temperature: 1.0
# projection of motion picture was blemed to continues of the eye.
#
# in lumière made an induningeplogicatic movicalinm vaym, 160, 187, 176.
#
#   modern a decage otence of the
#                                            archimederd, _see_ light source, 155
#
#   scientificus), 13iman’s fou
# aker offer anothapi ottographs interest in copied and the 19th
# century, with the _p
# reastionally translions and mathemation shows the sightiness
# could
# be introduced
# suffection developed as our scientific perforausance interest of
# curiod. his views of mathematicino and movemenan

# %%
# Temperature 0.5 seems to be the right mix between realistic and creative sequences
# The higher the number of epochs, the better the performance of the model
